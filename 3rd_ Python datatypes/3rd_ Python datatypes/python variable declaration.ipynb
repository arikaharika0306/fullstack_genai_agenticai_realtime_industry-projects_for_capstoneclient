# %%
5
# Out:
# 5

# %%
6
# Out:
# 6

# %%
5 + 6
# Out:
# 11

# %%
10 + 5
# Out:
# 15

# %%
10 - 5
# Out:
# 5

# %%
10 * 5
# Out:
# 50

# %%
10 / 5  # decimal (float division)
# Out:
# 2.0

# %%
10 // 5  #int division
# Out:
# 2

# %%
3 * 2
# Out:
# 6

# %%
3 ** 2
# Out:
# 9

# %%
10 % 5
# Out:
# 0

# %% [markdown]
# # we have understodd how to work with number

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
'hello'
# Out:
# 'hello'

# %%
" welcome to nareshit under expert mr.prakash senapati'
# Out:
#   Cell In[14], line 1
#     " welcome to nareshit under expert mr.prakash senapati'
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
" welcome to nareshit under expert mr.prakash senapati "
# Out:
# ' welcome to nareshit under expert mr.prakash senapati '

# %% [markdown]
# # python variable declaration

# %%
v = 5 # variable = value 
v
# Out:
# 5

# %%
5 = v
# Out:
#   Cell In[18], line 1
#     5 = v
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
1v = 20 #variable doesnot start with digit 
1v
# Out:
#   Cell In[19], line 1
#     1v = 20 #variable doesnot start with digit
#     ^
# SyntaxError: invalid decimal literal

# %%
v1 = 20
v1
# Out:
# 20

# %%
nit = 27
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 nit = 27
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit = 27
nit
# Out:
# 27

# %%
nit@ = 50
nit@
# Out:
#   Cell In[23], line 1
#     nit@ = 50
#          ^
# SyntaxError: invalid syntax

# %%
nit$ = 67
# Out:
#   Cell In[24], line 1
#     nit$ = 67
#        ^
# SyntaxError: invalid syntax

# %%
nit_ = 50
nit_
# Out:
# 50

# %%
_nit = 51
_nit
# Out:
# 51

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
def = 5
def
# Out:
#   Cell In[28], line 1
#     def = 5
#         ^
# SyntaxError: invalid syntax

# %%
if = 5
# Out:
#   Cell In[29], line 1
#     if = 5
#        ^
# SyntaxError: invalid syntax

# %%
IF = 5
IF
# Out:
# 5

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
del = 45
del
# Out:
#   Cell In[32], line 1
#     del = 45
#         ^
# SyntaxError: invalid syntax

# %%
# variable are completed

# %%
x = 10 
x
# Out:
# 10

# %%
x = 20
x
# Out:
# 20

# %%
x1 = 10
x1
# Out:
# 10

# %%
x1
# Out:
# 10

# %%
x
# Out:
# 20

# %%
10 + 5
10 - 5
10 * 5
# Out:
# 50

# %%
print(10+5)
print(10-5)
print(10*5)
# Out:
# 15
# 5
# 50

# %% [markdown]
# # python data type
# - int   (integer)
# - float (decimal)
# - bool (boolean) True or False
# - complex ( this datatype you wont find in any programing language except python)
# - string ( to handle text)

# %%
i = 5 # value without decimal 
i
# Out:
# 5

# %%
type(i)
# Out:
# int

# %%
id(i)
# Out:
# 140716583199784

# %% [markdown]
# # float

# %%
f = 109.78 
f
# Out:
# 109.78

# %%
type(f)
# Out:
# float

# %%
1f = 160.67
1f
# Out:
#   Cell In[13], line 1
#     1f = 160.67
#     ^
# SyntaxError: invalid decimal literal

# %%
f1 = 160.67
f1
# Out:
# 160.67

# %%
type(f1)
# Out:
# float

# %% [markdown]
# # boolean

# %%
b = true
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 b = true
#       2 b
#
# NameError: name 'true' is not defined

# %%
b = True
b
# Out:
# True

# %%
b1 = False
b1
# Out:
# False

# %%
b2 = None
b2

# %%
True + True
# Out:
# 2

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + False
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
False * False
# Out:
# 0

# %%
False / True
# Out:
# 0.0

# %%
False // True
# Out:
# 0

# %%
True / False # run time error
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # complex datatypes

# %%
c = 10 + 20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
d = 30+40j

# %%
print(c)
print(d)
# Out:
# (10+20j)
# (30+40j)

# %%
e = 2.3 + 3.4j
e
# Out:
# (2.3+3.4j)

# %%
e.real
# Out:
# 2.3

# %%
print(c)
print(d)
# Out:
# (10+20j)
# (30+40j)

# %%
c + d
# Out:
# (40+60j)

# %% [markdown]
# # string

# %%
s = 'welcom to genai and agentic ai batch'
s
# Out:
# 'welcom to genai and agentic ai batch'

# %%
s1= "welcom to genai and agentic ai batch"
s1
# Out:
# 'welcom to genai and agentic ai batch'

# %%
s2= '''welcom to genai and agentic ai batch'''
s2
# Out:
# 'welcom to genai and agentic ai batch'

# %%
s3 = ''' welcom 
            to 
        gen ai 
            agentic ai '''
s3
# Out:
# ' welcom \n            to \n        gen ai \n            agentic ai '

# %%
s = 'welcome'
s
# Out:
# 'welcome'

# %%
s[3] #forward index
# Out:
# 'c'

# %%
s[6]
# Out:
# 'e'

# %%
s
# Out:
# 'welcome'

# %%
s[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 s[7]
#
# IndexError: string index out of range

# %%
s
# Out:
# 'welcome'

# %%
s[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 s[10]
#
# IndexError: string index out of range

# %%
s
# Out:
# 'welcome'

# %%
s[-4]
# Out:
# 'c'

# %%
s
# Out:
# 'welcome'

# %%
s[-2]
# Out:
# 'm'

# %%
s[-7]
# Out:
# 'w'

# %%
s[-10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 s[-10]
#
# IndexError: string index out of range

# %%
s
# Out:
# 'welcome'

# %%
s[:]
