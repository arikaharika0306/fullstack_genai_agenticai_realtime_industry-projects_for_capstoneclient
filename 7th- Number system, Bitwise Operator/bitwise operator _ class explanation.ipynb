# %%
5
# Out:
# 5

# %%
6
# Out:
# 6

# %%
5 + 6
# Out:
# 11

# %%
10 + 5
# Out:
# 15

# %%
10 - 5
# Out:
# 5

# %%
10 * 5
# Out:
# 50

# %%
10 / 5  # decimal (float division)
# Out:
# 2.0

# %%
10 // 5  #int division
# Out:
# 2

# %%
3 * 2
# Out:
# 6

# %%
3 ** 2
# Out:
# 9

# %%
10 % 5
# Out:
# 0

# %% [markdown]
# # we have understodd how to work with number

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
'hello'
# Out:
# 'hello'

# %%
" welcome to nareshit under expert mr.prakash senapati'
# Out:
#   Cell In[14], line 1
#     " welcome to nareshit under expert mr.prakash senapati'
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
" welcome to nareshit under expert mr.prakash senapati "
# Out:
# ' welcome to nareshit under expert mr.prakash senapati '

# %% [markdown]
# # python variable declaration

# %%
v = 5 # variable = value 
v
# Out:
# 5

# %%
5 = v
# Out:
#   Cell In[18], line 1
#     5 = v
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
1v = 20 #variable doesnot start with digit 
1v
# Out:
#   Cell In[19], line 1
#     1v = 20 #variable doesnot start with digit
#     ^
# SyntaxError: invalid decimal literal

# %%
v1 = 20
v1
# Out:
# 20

# %%
nit = 27
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 nit = 27
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit = 27
nit
# Out:
# 27

# %%
nit@ = 50
nit@
# Out:
#   Cell In[23], line 1
#     nit@ = 50
#          ^
# SyntaxError: invalid syntax

# %%
nit$ = 67
# Out:
#   Cell In[24], line 1
#     nit$ = 67
#        ^
# SyntaxError: invalid syntax

# %%
nit_ = 50
nit_
# Out:
# 50

# %%
_nit = 51
_nit
# Out:
# 51

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
def = 5
def
# Out:
#   Cell In[28], line 1
#     def = 5
#         ^
# SyntaxError: invalid syntax

# %%
if = 5
# Out:
#   Cell In[29], line 1
#     if = 5
#        ^
# SyntaxError: invalid syntax

# %%
IF = 5
IF
# Out:
# 5

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
del = 45
del
# Out:
#   Cell In[32], line 1
#     del = 45
#         ^
# SyntaxError: invalid syntax

# %%
# variable are completed

# %%
x = 10 
x
# Out:
# 10

# %%
x = 20
x
# Out:
# 20

# %%
x1 = 10
x1
# Out:
# 10

# %%
x1
# Out:
# 10

# %%
x
# Out:
# 20

# %%
10 + 5
10 - 5
10 * 5
# Out:
# 50

# %%
print(10+5)
print(10-5)
print(10*5)
# Out:
# 15
# 5
# 50

# %% [markdown]
# # 5th

# %%
a = 5
b = 6

# %%
a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a = 6
a
# Out:
# 6

# %%
a == b
# Out:
# True

# %%
a ! = b
# Out:
#   Cell In[10], line 1
#     a ! = b
#       ^
# SyntaxError: invalid syntax

# %%
a != b
# Out:
# False

# %%
b = 7

# %%
print(a)
print(b)
# Out:
# 6
# 7

# %%
a >= 7
# Out:
# False

# %%
b <= 7
# Out:
# True

# %%
b = 6

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
a = 5
b = 4

# %%
a < 8 and b < 5
# Out:
# True

# %%
a < 8 and b < 2
# Out:
# False

# %%
a < 8 or b < 2
# Out:
# True

# %%
x = False
x
# Out:
# False

# %%
not x
# Out:
# True

# %%
y = True

# %%
not y
# Out:
# False

# %%
# print()

# %%
a=10
b=20
a
b
# Out:
# 20

# %%
a = 10
b = 20
c = 30

print(a) 
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
print(a, b, c)
# Out:
# 10 20 30

# %%
print(10) 
print(10, 20)
print('python')
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1 = 20
num2 = 30

add = num1+num2

print(add)
# Out:
# 50

# %%
print("Value of a is", a, "Value of b is", b, "Value of c is", c)
# Out:
# Value of a is 10 Value of b is 20 Value of c is 30

# %%
num1=20
num2=30

add=num1+num2
print('The addition of',num1,'and',num2,'is=',add)
# Out:
# The addition of 20 and 30 is= 50

# %%
num1=20
num2=30
num3=50

add=num1+num2+num3
print('The addition of',num1,'and',num2,'and', num3,'is=',add)
# Out:
# The addition of 20 and 30 and 50 is= 100

# %%
name='Python'
age=20
city='hyd'

print('My name is',name,'and i am',age,'years old form',city)
# Out:
# My name is Python and i am 20 years old form hyd

# %%
# print with format string

num1 =20
num2 =30
add =num1+num2

print('The addition of {} and {} is= {}'.format(num1,num2, add))
# Out:
# The addition of 20 and 30 is= 50

# %%
# print with format string

num1 =20
num2 =30
num3 = 50
add =num1+num2 + num3

print('The addition of {} and {} and {} is= {}'.format(num1,num2,num3,add))
# Out:
# The addition of 20 and 30 and 50 is= 100

# %%
# print with fstring method

num1 = 20
num2 = 30

add=num1+num2
print(f'The addition of {num1} and {num2} is= {add}')
# Out:
# The addition of 20 and 30 is= 50

# %%
print('hello') # 1st statement
print('good moorning') # 2nd statement)
# Out:
# hello
# good moorning

# %%
print('hello', end='--') # 1st statement
print('good moorning') # 2nd statement)
# Out:
# hello--good moorning

# %%
print('hello', end='****') # 1st statement
print('good moorning',end='--') # 2nd statement)
print('bye')
# Out:
# hello****good moorning--bye

# %%
print('hello','hai','how are you',sep='--->')
# Out:
# hello--->hai--->how are you

# %%
print('hello','hai','how are you',sep='@')
# Out:
# hello@hai@how are you

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %% [markdown]
# # 7th

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
hex(10)
# Out:
# '0xa'

# %%
hex(11)
# Out:
# '0xb'

# %%
hex(15)
# Out:
# '0xf'

# %%
hex(16)
# Out:
# '0x10'

# %%
int(0x10)
# Out:
# 16

# %% [markdown]
# #  & operator

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
bin(35)
# Out:
# '0b100011'

# %%
bin(40)
# Out:
# '0b101000'

# %%
35 ^ 40
# Out:
# 11

# %%
#left shift

# %%
12 << 2
# Out:
# 48

# %%
12 << 1
# Out:
# 24

# %% [markdown]
# # Right Shift

# %%
12>>2
# Out:
# 3

# %%
~12
# Out:
# -13

# %%
~34
# Out:
# -35

# %%
x = sqrt(25)
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 x = sqrt(25)
#       2 x
#
# NameError: name 'sqrt' is not defined

# %%
import math

# %%
x = math.sqrt(25) 
x
# Out:
# 5.0

# %%
m.sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 m.sqrt(25)
#
# NameError: name 'm' is not defined

# %%
import math as m 
m.sqrt(25)
# Out:
# 5.0

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
#help()

# %%
m.floor(4.5)
# Out:
# 4

# %%
m.ceil(4.5)
# Out:
# 5

# %%
#help(math)

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
pi = 3.14
pi
# Out:
# 3.14

# %%
pi = 4.15
pi
# Out:
# 4.15

# %%
from math import sqrt, pow 

print(math.sqrt(35))

print(math.pow(2,3))
# Out:
# 5.916079783099616
# 8.0
# 2

# %%
from math import * 

print(math.sqrt(35))
print(math.pow(2,3)) 
print(math.floor(2.3))
print(math.ceil(2.3))
# Out:
# 5.916079783099616
# 8.0
# 2
# 3
